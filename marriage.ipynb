# %% [markdown]
# ### Średni wiek małżeństwa kobiet w Polsce ###

# %%
# pobierz dane z pliku demo_nind_linear.csv i wyświetl je w pandas
# usuń niepotrzebne kolumny i wyświetl pierwsze 5 wierszy
# stwórz wykres liniowy z danymi z kolumny OBS_VALUE

# %%
# podziel dane na zbiór treningowy i testowy (80% trening, 20% test)
# stwórz walidację walk forward validation z naiwnym modelem prognozowania (ostatnia wartość jako prognoza na następną)
# oblicz RMSE dla prognoz na zbiorze testowym

# %%
# użyje modelu do przewidywania następnej wartości w szeregu czasowym - Exponential Smoothing

# %%
# dostrój parametry modelu Exponential Smoothing

# %%
# Użyj najlepszego modelu do przewidywania

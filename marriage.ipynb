# %% [markdown]
# ### Średni wiek małżeństwa kobiet w Polsce ###

# %%
# pobierz dane z pliku demo_nind_linear.csv i wyświetl je w pandas

# %%
# stwórz walidację walk forward validation

# %%
# użyje modelu do przewidywania następnej wartości w szeregu czasowym - Exponential Smoothing

# %%
# dostroj parametry modelu Exponential Smoothing

# %%
# Użyj najlepszego moedlu do przewidywania
